# %% [markdown]
# <img src='images/vpython.png' width="230px">
#
# # <font color='#333333'>Iris Dataset<font>
# ## <font color='#333333'>A Vertica ML Python tutorial to understand how to use the library.<font>
#
# The Iris flower data set or Fisher's Iris data set is a multivariate data set introduced by the British statistician and biologist Ronald Fisher in his 1936 paper The use of multiple measurements in taxonomic problems as an example of linear discriminant analysis. <br>
#
# The data set consists of 50 samples from each of three species of Iris (Iris setosa, Iris virginica and Iris versicolor). Four features were measured from each sample: the length and the width of the sepals and petals, in centimetres. Based on the combination of these four features, Fisher developed a linear discriminant model to distinguish the species from each other.
#
# <img src='images/irises.png' width="600px">
#
# ### <font color='#555555'>Connection to the Vertica Database using a DSN.<font>
#
# In order to use the Vertica ML Python Library and begin the searches, we need first to connect to the Vertica Database. We can use an ODBC connection using a DSN.

# %%
import pyodbc
cur=pyodbc.connect("DSN=VerticaDSN").cursor() # It is the cursor used for all the queries to our Database.

# %% [markdown]
# ### <font color='#555555'>Initialization<font>
#
# We can now import the VPython library and especially the RVD (Resilient Vertica Dataset) object.

# %%
from vertica_ml_python import RVD
from vertica_ml_python import read_csv # This function will help us to load the csv file in the Database.
from vertica_ml_python import drop_table # This function will help us to drop the unnecessary tables.

# %% [markdown]
# Let's now drop the table iris from our Database (if it exists) in order to use the read_csv parser.

# %%
drop_table("Iris",cur)
# Out:
# The table Iris was successfully dropped.

# %% [markdown]
# Let's now try to parse the csv files.

# %%
iris=read_csv('../datasets/Iris.csv',cur)
# Out:
# The parser guess the following columns and types:
# Id: Integer
# PetalLengthCm: Numeric(5,2)
# PetalWidthCm: Numeric(5,2)
# SepalLengthCm: Numeric(5,2)
# SepalWidthCm: Numeric(5,2)
# Species: Varchar(30)
# Illegal characters in the columns names will be erased.
# Is any type wrong?
# If one of the types is not correct, it will be considered as Varchar(100).
# 0 - There is one type that I want to modify.
# 1 - I wish to continue.
# 2 - I wish to see the columns and their types again.
# 1
# The table Iris has been successfully created.

# %% [markdown]
# If the table is already in the Database. We can create the RVD as follows:

# %%
iris=RVD('Iris',cur)

# %% [markdown]
# We can also create the RVD using directly the DSN:

# %%
iris=RVD('Iris',dsn="VerticaDSN")

# %% [markdown]
# ### <font color='#555555'>Data Exploration and Cleaning<font>
#
# Great, we have now our RVD object. All its methods will send SQL queries directly to Vertica in order to compute all the aggregations needed. In that case, nothing is loaded inside our machine except the final results computed by Vertica. All the users transformations are kept in mind and then used to send the final query.
#
# During this tutorial, we will try to understand the object thanks to this small dataset. Let first see what it looks like.

# %%
iris.head(5)
# Out:
# <table style="border-collapse: collapse; border: 2px solid rgb(200,200,200)"><tr style="{border: 1px solid rgb(200,200,200);}"><td style="border-bottom: 1px solid #DDD;font-size:1.02em;background-color:#DDD"><b></b></td><td style="font-size:1.02em;background-color:#DDD"><b>Id</b></td><td style="font-size:1.02em;background-color:#DDD"><b>PetalLengthCm</b></td><td style="font-size:1.02em;background-color:#DDD"><b>PetalWidthCm</b></td><td style="font-size:1.02em;background-color:#DDD"><b>SepalLengthCm</b></td><td style="font-size:1.02em;background-color:#DDD"><b>SepalWidthCm</b></td><td style="font-size:1.02em;background-color:#DDD"><b>Species</b></td></tr><tr style="{border: 1px solid rgb(200,200,200);}"><td style="border-bottom: 1px solid #DDD;font-size:1.02em;background-color:#DDD"><b>0</b></td><td style="border: 1px solid rgb(200,200,200);">1</td><td style="border: 1px solid rgb(200,200,200);">1.40</td><td style="border: 1px solid rgb(200,200,200);">0.20</td><td style="border: 1px solid rgb(200,200,200);">5.10</td><td style="border: 1px solid rgb(200,200,200);">3.50</td><td style="border: 1px solid rgb(200,200,200);">Iris-setosa</td></tr><tr style="{border: 1px solid rgb(200,200,200);}"><td style="border-bottom: 1px solid #DDD;font-size:1.02em;background-color:#DDD"><b>1</b></td><td style="border: 1px solid rgb(200,200,200);">2</td><td style="border: 1px solid rgb(200,200,200);">1.40</td><td style="border: 1px solid rgb(200,200,200);">0.20</td><td style="border: 1px solid rgb(200,200,200);">4.90</td><td style="border: 1px solid rgb(200,200,200);">3.00</td><td style="border: 1px solid rgb(200,200,200);">Iris-setosa</td></tr><tr style="{border: 1px solid rgb(200,200,200);}"><td style="border-bottom: 1px solid #DDD;font-size:1.02em;background-color:#DDD"><b>2</b></td><td style="border: 1px solid rgb(200,200,200);">3</td><td style="border: 1px solid rgb(200,200,200);">1.30</td><td style="border: 1px solid rgb(200,200,200);">0.20</td><td style="border: 1px solid rgb(200,200,200);">4.70</td><td style="border: 1px solid rgb(200,200,200);">3.20</td><td style="border: 1px solid rgb(200,200,200);">Iris-setosa</td></tr><tr style="{border: 1px solid rgb(200,200,200);}"><td style="border-bottom: 1px solid #DDD;font-size:1.02em;background-color:#DDD"><b>3</b></td><td style="border: 1px solid rgb(200,200,200);">4</td><td style="border: 1px solid rgb(200,200,200);">1.50</td><td style="border: 1px solid rgb(200,200,200);">0.20</td><td style="border: 1px solid rgb(200,200,200);">4.60</td><td style="border: 1px solid rgb(200,200,200);">3.10</td><td style="border: 1px solid rgb(200,200,200);">Iris-setosa</td></tr><tr style="{border: 1px solid rgb(200,200,200);}"><td style="border-bottom: 1px solid #DDD;font-size:1.02em;background-color:#DDD"><b>4</b></td><td style="border: 1px solid rgb(200,200,200);">5</td><td style="border: 1px solid rgb(200,200,200);">1.40</td><td style="border: 1px solid rgb(200,200,200);">0.20</td><td style="border: 1px solid rgb(200,200,200);">5.00</td><td style="border: 1px solid rgb(200,200,200);">3.60</td><td style="border: 1px solid rgb(200,200,200);">Iris-setosa</td></tr><tr><td style="border-top: 1px solid #DDD;background-color:#DDD"></td><td style="border: 1px solid rgb(200,200,200);">...</td><td style="border: 1px solid rgb(200,200,200);">...</td><td style="border: 1px solid rgb(200,200,200);">...</td><td style="border: 1px solid rgb(200,200,200);">...</td><td style="border: 1px solid rgb(200,200,200);">...</td><td style="border: 1px solid rgb(200,200,200);">...</td></tr></table>
# Name: Iris, Number of rows: 150, Number of columns: 6

# %% [markdown]
# The column Id is useless, we can drop it.

# %%
iris["Id"].drop_column()
# Out:
# RVC 'Id' deleted from the RVD.

# %% [markdown]
# In this dataset, we have four relevant columns that will be used for predictions.

# %%
iris.describe()
# Out:
# <table style="border-collapse: collapse; border: 2px solid rgb(200,200,200)"><tr style="{border: 1px solid rgb(200,200,200);}"><td style="border-bottom: 1px solid #DDD;font-size:1.02em;background-color:#DDD"><b></b></td><td style="font-size:1.02em;background-color:#DDD"><b>count</b></td><td style="font-size:1.02em;background-color:#DDD"><b>mean</b></td><td style="font-size:1.02em;background-color:#DDD"><b>std</b></td><td style="font-size:1.02em;background-color:#DDD"><b>min</b></td><td style="font-size:1.02em;background-color:#DDD"><b>25%</b></td><td style="font-size:1.02em;background-color:#DDD"><b>50%</b></td><td style="font-size:1.02em;background-color:#DDD"><b>75%</b></td><td style="font-size:1.02em;background-color:#DDD"><b>max</b></td><td style="font-size:1.02em;background-color:#DDD"><b>cardinality</b></td></tr><tr style="{border: 1px solid rgb(200,200,200);}"><td style="border-bottom: 1px solid #DDD;font-size:1.02em;background-color:#DDD"><b>PetalLengthCm</b></td><td style="border: 1px solid rgb(200,200,200);">150</td><td style="border: 1px solid rgb(200,200,200);">3.75866666666667</td><td style="border: 1px solid rgb(200,200,200);">1.76442041995226</td><td style="border: 1px solid rgb(200,200,200);">1.0</td><td style="border: 1px solid rgb(200,200,200);">1.6</td><td style="border: 1px solid rgb(200,200,200);">4.35</td><td style="border: 1px solid rgb(200,200,200);">5.1</td><td style="border: 1px solid rgb(200,200,200);">6.9</td><td style="border: 1px solid rgb(200,200,200);">43</td></tr><tr style="{border: 1px solid rgb(200,200,200);}"><td style="border-bottom: 1px solid #DDD;font-size:1.02em;background-color:#DDD"><b>PetalWidthCm</b></td><td style="border: 1px solid rgb(200,200,200);">150</td><td style="border: 1px solid rgb(200,200,200);">1.19866666666667</td><td style="border: 1px solid rgb(200,200,200);">0.763160741700841</td><td style="border: 1px solid rgb(200,200,200);">0.1</td><td style="border: 1px solid rgb(200,200,200);">0.3</td><td style="border: 1px solid rgb(200,200,200);">1.3</td><td style="border: 1px solid rgb(200,200,200);">1.8</td><td style="border: 1px solid rgb(200,200,200);">2.5</td><td style="border: 1px solid rgb(200,200,200);">22</td></tr><tr style="{border: 1px solid rgb(200,200,200);}"><td style="border-bottom: 1px solid #DDD;font-size:1.02em;background-color:#DDD"><b>SepalLengthCm</b></td><td style="border: 1px solid rgb(200,200,200);">150</td><td style="border: 1px solid rgb(200,200,200);">5.84333333333333</td><td style="border: 1px solid rgb(200,200,200);">0.828066127977864</td><td style="border: 1px solid rgb(200,200,200);">4.3</td><td style="border: 1px solid rgb(200,200,200);">5.1</td><td style="border: 1px solid rgb(200,200,200);">5.8</td><td style="border: 1px solid rgb(200,200,200);">6.4</td><td style="border: 1px solid rgb(200,200,200);">7.9</td><td style="border: 1px solid rgb(200,200,200);">35</td></tr><tr style="{border: 1px solid rgb(200,200,200);}"><td style="border-bottom: 1px solid #DDD;font-size:1.02em;background-color:#DDD"><b>SepalWidthCm</b></td><td style="border: 1px solid rgb(200,200,200);">150</td><td style="border: 1px solid rgb(200,200,200);">3.054</td><td style="border: 1px solid rgb(200,200,200);">0.433594311362174</td><td style="border: 1px solid rgb(200,200,200);">2.0</td><td style="border: 1px solid rgb(200,200,200);">2.8</td><td style="border: 1px solid rgb(200,200,200);">3.0</td><td style="border: 1px solid rgb(200,200,200);">3.3</td><td style="border: 1px solid rgb(200,200,200);">4.4</td><td style="border: 1px solid rgb(200,200,200);">23</td></tr></table>

# %% [markdown]
# In this dataset, there is no outliers and no missing values as the biologist Ronald Fisher measured himself all the flowers.

# %%
iris.missing()
# Out:
# <table style="border-collapse: collapse; border: 2px solid rgb(200,200,200)"><tr style="{border: 1px solid rgb(200,200,200);}"><td style="border-bottom: 1px solid #DDD;font-size:1.02em;background-color:#DDD"><b></b></td><td style="font-size:1.02em;background-color:#DDD"><b>total</b></td><td style="font-size:1.02em;background-color:#DDD"><b>percent</b></td></tr><tr style="{border: 1px solid rgb(200,200,200);}"><td style="border-bottom: 1px solid #DDD;font-size:1.02em;background-color:#DDD"><b>Species</b></td><td style="border: 1px solid rgb(200,200,200);">0</td><td style="border: 1px solid rgb(200,200,200);">0.0</td></tr><tr style="{border: 1px solid rgb(200,200,200);}"><td style="border-bottom: 1px solid #DDD;font-size:1.02em;background-color:#DDD"><b>SepalLengthCm</b></td><td style="border: 1px solid rgb(200,200,200);">0</td><td style="border: 1px solid rgb(200,200,200);">0.0</td></tr><tr style="{border: 1px solid rgb(200,200,200);}"><td style="border-bottom: 1px solid #DDD;font-size:1.02em;background-color:#DDD"><b>PetalWidthCm</b></td><td style="border: 1px solid rgb(200,200,200);">0</td><td style="border: 1px solid rgb(200,200,200);">0.0</td></tr><tr style="{border: 1px solid rgb(200,200,200);}"><td style="border-bottom: 1px solid #DDD;font-size:1.02em;background-color:#DDD"><b>PetalLengthCm</b></td><td style="border: 1px solid rgb(200,200,200);">0</td><td style="border: 1px solid rgb(200,200,200);">0.0</td></tr><tr style="{border: 1px solid rgb(200,200,200);}"><td style="border-bottom: 1px solid #DDD;font-size:1.02em;background-color:#DDD"><b>SepalWidthCm</b></td><td style="border: 1px solid rgb(200,200,200);">0</td><td style="border: 1px solid rgb(200,200,200);">0.0</td></tr></table>

# %% [markdown]
# Let's explore a little deeper the dataset.

# %%
iris.scatter(columns=["PetalLengthCm","SepalLengthCm","Species"])
iris.scatter(columns=["PetalWidthCm","SepalWidthCm","Species"])
iris.scatter(columns=["PetalWidthCm","PetalLengthCm","Species"])
iris.scatter(columns=["SepalWidthCm","PetalLengthCm","Species"])

# %% [markdown]
# Wow, there is really a border between each species! Let's see some 3D plots.

# %%
iris.scatter(columns=["PetalLengthCm","SepalLengthCm","SepalWidthCm","Species"])
iris.scatter(columns=["PetalLengthCm","SepalLengthCm","PetalWidthCm","Species"])
iris.scatter(columns=["PetalLengthCm","SepalWidthCm","PetalWidthCm","Species"])

# %% [markdown]
# Iris setosa flowers are very easy to predict. However, some of the two other species can be hard to predict. In order to do so, many algorithms are possibles:
# <ul>
#     <li>Logistic Regression or SVM using the one hot encoding of our 3 species
#     <li>Naive Bayes or Random Forest
#     <li>Kmeans with 3 clusters
# </ul>
# First we will use a Kmeans Clustering to try to predict the 3 species. After we will use the SVM in order to see how we can predict variables of multiple classes using a binary classifier.

# %% [markdown]
# ### <font color='#555555'>Kmeans Clustering<font>
# First let's import the Kmeans algorithm.

# %%
from vertica_ml_python import kmeans
from vertica_ml_python import drop_model

drop_model("iris_kmeans",cur)
# Out:
# The model iris_kmeans was successfully dropped.

# %% [markdown]
# We can see the optimal number of clusters using the elbow curve.

# %%
from vertica_ml_python import elbow
elbow(input_relation="Iris",input_columns=["PetalLengthCm","SepalLengthCm","PetalWidthCm","SepalWidthCm"],cursor=cur,
         max_num_cluster=8)
# Out:
# <table style="border-collapse: collapse; border: 2px solid rgb(200,200,200)"><tr style="{border: 1px solid rgb(200,200,200);}"><td style="border-bottom: 1px solid #DDD;font-size:1.02em;background-color:#DDD"><b>num_clusters</b></td><td style="font-size:1.02em;background-color:#DDD"><b>all_within_cluster_SS</b></td></tr><tr style="{border: 1px solid rgb(200,200,200);}"><td style="border-bottom: 1px solid #DDD;font-size:1.02em;background-color:#DDD"><b>1</b></td><td style="border: 1px solid rgb(200,200,200);">680.8244</td></tr><tr style="{border: 1px solid rgb(200,200,200);}"><td style="border-bottom: 1px solid #DDD;font-size:1.02em;background-color:#DDD"><b>2</b></td><td style="border: 1px solid rgb(200,200,200);">152.36871</td></tr><tr style="{border: 1px solid rgb(200,200,200);}"><td style="border-bottom: 1px solid #DDD;font-size:1.02em;background-color:#DDD"><b>3</b></td><td style="border: 1px solid rgb(200,200,200);">78.945066</td></tr><tr style="{border: 1px solid rgb(200,200,200);}"><td style="border-bottom: 1px solid #DDD;font-size:1.02em;background-color:#DDD"><b>4</b></td><td style="border: 1px solid rgb(200,200,200);">57.473273</td></tr><tr style="{border: 1px solid rgb(200,200,200);}"><td style="border-bottom: 1px solid #DDD;font-size:1.02em;background-color:#DDD"><b>5</b></td><td style="border: 1px solid rgb(200,200,200);">46.801702</td></tr><tr style="{border: 1px solid rgb(200,200,200);}"><td style="border-bottom: 1px solid #DDD;font-size:1.02em;background-color:#DDD"><b>6</b></td><td style="border: 1px solid rgb(200,200,200);">38.93874</td></tr><tr style="{border: 1px solid rgb(200,200,200);}"><td style="border-bottom: 1px solid #DDD;font-size:1.02em;background-color:#DDD"><b>7</b></td><td style="border: 1px solid rgb(200,200,200);">34.968593</td></tr></table>

# %% [markdown]
# As expected, 3 is the optimal number of clusters as the all_within_cluster_SS decreases slowly after this point. We can then create the model.

# %%
iris_kmeans=kmeans(model_name="iris_kmeans",input_relation="Iris",
                   input_columns=["PetalLengthCm","SepalLengthCm","PetalWidthCm","SepalWidthCm"],
                   num_clusters=3,cursor=cur,initial_centers=[(1,2,3,4),(2,3,4,5),(3,4,5,6)])

# %% [markdown]
# Let's see what the model looks like.

# %%
print(iris_kmeans)
iris_kmeans.cluster_SS()
# Out:
# <table style="border-collapse: collapse; border: 2px solid rgb(200,200,200)"><tr style="{border: 1px solid rgb(200,200,200);}"><td style="border-bottom: 1px solid #DDD;font-size:1.02em;background-color:#DDD"><b></b></td><td style="font-size:1.02em;background-color:#DDD"><b>PetalLengthCm</b></td><td style="font-size:1.02em;background-color:#DDD"><b>SepalLengthCm</b></td><td style="font-size:1.02em;background-color:#DDD"><b>PetalWidthCm</b></td><td style="font-size:1.02em;background-color:#DDD"><b>SepalWidthCm</b></td></tr><tr style="{border: 1px solid rgb(200,200,200);}"><td style="border-bottom: 1px solid #DDD;font-size:1.02em;background-color:#DDD"><b>0</b></td><td style="border: 1px solid rgb(200,200,200);">1.464</td><td style="border: 1px solid rgb(200,200,200);">5.006</td><td style="border: 1px solid rgb(200,200,200);">0.244</td><td style="border: 1px solid rgb(200,200,200);">3.418</td></tr><tr style="{border: 1px solid rgb(200,200,200);}"><td style="border-bottom: 1px solid #DDD;font-size:1.02em;background-color:#DDD"><b>1</b></td><td style="border: 1px solid rgb(200,200,200);">4.39354838709677</td><td style="border: 1px solid rgb(200,200,200);">5.90161290322581</td><td style="border: 1px solid rgb(200,200,200);">1.43387096774194</td><td style="border: 1px solid rgb(200,200,200);">2.74838709677419</td></tr><tr style="{border: 1px solid rgb(200,200,200);}"><td style="border-bottom: 1px solid #DDD;font-size:1.02em;background-color:#DDD"><b>2</b></td><td style="border: 1px solid rgb(200,200,200);">5.7421052631579</td><td style="border: 1px solid rgb(200,200,200);">6.85</td><td style="border: 1px solid rgb(200,200,200);">2.07105263157895</td><td style="border: 1px solid rgb(200,200,200);">3.07368421052632</td></tr></table>
# model_type='kmeans'
# model_name='iris_kmeans'
# input_relation='Iris'
# input_columns='PetalLengthCm,SepalLengthCm,PetalWidthCm,SepalWidthCm'
# <table style="border-collapse: collapse; border: 2px solid rgb(200,200,200)"><tr style="{border: 1px solid rgb(200,200,200);}"><td style="border-bottom: 1px solid #DDD;font-size:1.02em;background-color:#DDD"><b></b></td><td style="font-size:1.02em;background-color:#DDD"><b>Cluster SS</b></td></tr><tr style="{border: 1px solid rgb(200,200,200);}"><td style="border-bottom: 1px solid #DDD;font-size:1.02em;background-color:#DDD"><b>0</b></td><td style="border: 1px solid rgb(200,200,200);">15.2404</td></tr><tr style="{border: 1px solid rgb(200,200,200);}"><td style="border-bottom: 1px solid #DDD;font-size:1.02em;background-color:#DDD"><b>1</b></td><td style="border: 1px solid rgb(200,200,200);">39.820968</td></tr><tr style="{border: 1px solid rgb(200,200,200);}"><td style="border-bottom: 1px solid #DDD;font-size:1.02em;background-color:#DDD"><b>2</b></td><td style="border: 1px solid rgb(200,200,200);">23.879474</td></tr></table>
# [15.2404, 39.820968, 23.879474]

# %% [markdown]
# We can also see the importance of each feature.

# %%
iris_kmeans.features_importance()
# Out:
# <table style="border-collapse: collapse; border: 2px solid rgb(200,200,200)"><tr style="{border: 1px solid rgb(200,200,200);}"><td style="border-bottom: 1px solid #DDD;font-size:1.02em;background-color:#DDD"><b></b></td><td style="font-size:1.02em;background-color:#DDD"><b>Importance</b></td></tr><tr style="{border: 1px solid rgb(200,200,200);}"><td style="border-bottom: 1px solid #DDD;font-size:1.02em;background-color:#DDD"><b>SepalWidthCm</b></td><td style="border: 1px solid rgb(200,200,200);">0.189935818337476</td></tr><tr style="{border: 1px solid rgb(200,200,200);}"><td style="border-bottom: 1px solid #DDD;font-size:1.02em;background-color:#DDD"><b>SepalLengthCm</b></td><td style="border: 1px solid rgb(200,200,200);">0.23234341611857398</td></tr><tr style="{border: 1px solid rgb(200,200,200);}"><td style="border-bottom: 1px solid #DDD;font-size:1.02em;background-color:#DDD"><b>PetalWidthCm</b></td><td style="border: 1px solid rgb(200,200,200);">0.2835830211296191</td></tr><tr style="{border: 1px solid rgb(200,200,200);}"><td style="border-bottom: 1px solid #DDD;font-size:1.02em;background-color:#DDD"><b>PetalLengthCm</b></td><td style="border: 1px solid rgb(200,200,200);">0.294137744414331</td></tr></table>

# %% [markdown]
# Let's add the clusters to our RVD.

# %%
name=iris_kmeans.add_to_rvd(iris)
print(iris)
# Out:
# The new RVC 'kmeans_cluster1045' was added to the RVD.
# <table style="border-collapse: collapse; border: 2px solid rgb(200,200,200)"><tr style="{border: 1px solid rgb(200,200,200);}"><td style="border-bottom: 1px solid #DDD;font-size:1.02em;background-color:#DDD"><b></b></td><td style="font-size:1.02em;background-color:#DDD"><b>PetalLengthCm</b></td><td style="font-size:1.02em;background-color:#DDD"><b>PetalWidthCm</b></td><td style="font-size:1.02em;background-color:#DDD"><b>SepalLengthCm</b></td><td style="font-size:1.02em;background-color:#DDD"><b>SepalWidthCm</b></td><td style="font-size:1.02em;background-color:#DDD"><b>Species</b></td><td style="font-size:1.02em;background-color:#DDD"><b>kmeans_cluster1045</b></td></tr><tr style="{border: 1px solid rgb(200,200,200);}"><td style="border-bottom: 1px solid #DDD;font-size:1.02em;background-color:#DDD"><b>0</b></td><td style="border: 1px solid rgb(200,200,200);">1.40</td><td style="border: 1px solid rgb(200,200,200);">0.20</td><td style="border: 1px solid rgb(200,200,200);">5.10</td><td style="border: 1px solid rgb(200,200,200);">3.50</td><td style="border: 1px solid rgb(200,200,200);">Iris-setosa</td><td style="border: 1px solid rgb(200,200,200);">0</td></tr><tr style="{border: 1px solid rgb(200,200,200);}"><td style="border-bottom: 1px solid #DDD;font-size:1.02em;background-color:#DDD"><b>1</b></td><td style="border: 1px solid rgb(200,200,200);">1.40</td><td style="border: 1px solid rgb(200,200,200);">0.20</td><td style="border: 1px solid rgb(200,200,200);">4.90</td><td style="border: 1px solid rgb(200,200,200);">3.00</td><td style="border: 1px solid rgb(200,200,200);">Iris-setosa</td><td style="border: 1px solid rgb(200,200,200);">0</td></tr><tr style="{border: 1px solid rgb(200,200,200);}"><td style="border-bottom: 1px solid #DDD;font-size:1.02em;background-color:#DDD"><b>2</b></td><td style="border: 1px solid rgb(200,200,200);">1.30</td><td style="border: 1px solid rgb(200,200,200);">0.20</td><td style="border: 1px solid rgb(200,200,200);">4.70</td><td style="border: 1px solid rgb(200,200,200);">3.20</td><td style="border: 1px solid rgb(200,200,200);">Iris-setosa</td><td style="border: 1px solid rgb(200,200,200);">0</td></tr><tr style="{border: 1px solid rgb(200,200,200);}"><td style="border-bottom: 1px solid #DDD;font-size:1.02em;background-color:#DDD"><b>3</b></td><td style="border: 1px solid rgb(200,200,200);">1.50</td><td style="border: 1px solid rgb(200,200,200);">0.20</td><td style="border: 1px solid rgb(200,200,200);">4.60</td><td style="border: 1px solid rgb(200,200,200);">3.10</td><td style="border: 1px solid rgb(200,200,200);">Iris-setosa</td><td style="border: 1px solid rgb(200,200,200);">0</td></tr><tr style="{border: 1px solid rgb(200,200,200);}"><td style="border-bottom: 1px solid #DDD;font-size:1.02em;background-color:#DDD"><b>4</b></td><td style="border: 1px solid rgb(200,200,200);">1.40</td><td style="border: 1px solid rgb(200,200,200);">0.20</td><td style="border: 1px solid rgb(200,200,200);">5.00</td><td style="border: 1px solid rgb(200,200,200);">3.60</td><td style="border: 1px solid rgb(200,200,200);">Iris-setosa</td><td style="border: 1px solid rgb(200,200,200);">0</td></tr><tr style="{border: 1px solid rgb(200,200,200);}"><td style="border-bottom: 1px solid #DDD;font-size:1.02em;background-color:#DDD"><b>5</b></td><td style="border: 1px solid rgb(200,200,200);">1.70</td><td style="border: 1px solid rgb(200,200,200);">0.40</td><td style="border: 1px solid rgb(200,200,200);">5.40</td><td style="border: 1px solid rgb(200,200,200);">3.90</td><td style="border: 1px solid rgb(200,200,200);">Iris-setosa</td><td style="border: 1px solid rgb(200,200,200);">0</td></tr><tr style="{border: 1px solid rgb(200,200,200);}"><td style="border-bottom: 1px solid #DDD;font-size:1.02em;background-color:#DDD"><b>6</b></td><td style="border: 1px solid rgb(200,200,200);">1.40</td><td style="border: 1px solid rgb(200,200,200);">0.30</td><td style="border: 1px solid rgb(200,200,200);">4.60</td><td style="border: 1px solid rgb(200, ...
# Name: Iris, Number of rows: 150, Number of columns: 6

# %% [markdown]
# As expected the Iris Setosa is perfectly predicted. Let's explore our new column.

# %%
iris[name].hist(method="count")
iris["Species"].hist(method="count")

# %% [markdown]
# Let's compare the most interesting plots.

# %%
iris.scatter(columns=["PetalWidthCm","SepalWidthCm","Species"])
iris.scatter(columns=["PetalWidthCm","SepalWidthCm",name])

# %% [markdown]
# Okay! So cluster 0 is the Iris Setosa, 1 is the Iris Versicolor and 2 is the Iris Virginica. Iris Setosa is perfectly predicted while there are some mistakes for the two others. Let's see our accuracy.

# %%
iris["Species"].decode(["Iris-setosa","Iris-versicolor"],[0,1],2)
iris.add_feature("cluster_comparaison",iris[name].final_transformation()+"="+iris["Species"].final_transformation())
iris["cluster_comparaison"].describe()
# Out:
# The new RVC 'cluster_comparaison' was added to the RVD.
# <table style="border-collapse: collapse; border: 2px solid rgb(200,200,200)"><tr style="{border: 1px solid rgb(200,200,200);}"><td style="border-bottom: 1px solid #DDD;font-size:1.02em;background-color:#DDD"><b></b></td><td style="font-size:1.02em;background-color:#DDD"><b>value</b></td></tr><tr style="{border: 1px solid rgb(200,200,200);}"><td style="border-bottom: 1px solid #DDD;font-size:1.02em;background-color:#DDD"><b>t</b></td><td style="border: 1px solid rgb(200,200,200);">134</td></tr><tr style="{border: 1px solid rgb(200,200,200);}"><td style="border-bottom: 1px solid #DDD;font-size:1.02em;background-color:#DDD"><b>f</b></td><td style="border: 1px solid rgb(200,200,200);">16</td></tr></table>

# %% [markdown]
# We have an accuracy of {{round(134/150*100,2)}}% which is quite good. However, we can still improve it.

# %% [markdown]
# ### <font color='#555555'>SVM Classification<font>
# #### <font color='#666666'>SVM Classification on Iris Setosa<font>
# Let's now try to see what we can do with the SVM classifier.

# %% [markdown]
# We must use the one hot encoder in order to have multiple binary variables.

# %%
iris=RVD("Iris",dsn="VerticaDSN")
iris["Species"].one_hot_encoder()
iris["Species_Iris_setosa"].hist(method="count")
# Out:
# 3 new features: Species_Iris_setosa, Species_Iris_versicolor, Species_Iris_virginica

# %% [markdown]
# We can save our RVD as a view.

# %%
from vertica_ml_python import drop_view
drop_view("iris_temp",cur)
iris.save("iris_temp")
# Out:
# The view iris_temp was successfully dropped.
# The RVD was successfully saved.

# %% [markdown]
# We can now try to find the hyperplan which will separate the data. We will create many SVM in order to see the plan in many different dimensions.

# %% [markdown]
# ##### <font color='#555555'>SVM with only one feature<font>

# %%
from vertica_ml_python import svm_classifier
drop_model("svm_iris",cur)
svm_iris=svm_classifier(model_name="svm_iris",input_relation="iris_temp",response_column="Species_Iris_setosa",
                   predictor_columns=["PetalLengthCm"],cursor=cur)
svm_iris.plot()
# Out:
# The model svm_iris was successfully dropped.

# %% [markdown]
# ##### <font color='#555555'>SVM with only two features<font>

# %%
from vertica_ml_python import svm_classifier
drop_model("svm_iris",cur)
svm_iris=svm_classifier(model_name="svm_iris",input_relation="iris_temp",response_column="Species_Iris_setosa",
                   predictor_columns=["PetalLengthCm","SepalLengthCm",],cursor=cur)
print(svm_iris)
svm_iris.plot()
# Out:
# The model svm_iris was successfully dropped.
# <table style="border-collapse: collapse; border: 2px solid rgb(200,200,200)"><tr style="{border: 1px solid rgb(200,200,200);}"><td style="border-bottom: 1px solid #DDD;font-size:1.02em;background-color:#DDD"><b></b></td><td style="font-size:1.02em;background-color:#DDD"><b>coefficient</b></td></tr><tr style="{border: 1px solid rgb(200,200,200);}"><td style="border-bottom: 1px solid #DDD;font-size:1.02em;background-color:#DDD"><b>Intercept</b></td><td style="border: 1px solid rgb(200,200,200);">0.22005691793408</td></tr><tr style="{border: 1px solid rgb(200,200,200);}"><td style="border-bottom: 1px solid #DDD;font-size:1.02em;background-color:#DDD"><b>petallengthcm</b></td><td style="border: 1px solid rgb(200,200,200);">-1.21492250709494</td></tr><tr style="{border: 1px solid rgb(200,200,200);}"><td style="border-bottom: 1px solid #DDD;font-size:1.02em;background-color:#DDD"><b>sepallengthcm</b></td><td style="border: 1px solid rgb(200,200,200);">0.563205058441283</td></tr></table>
# model_type='svm_classifier'
# model_name='svm_iris'
# input_relation='iris_temp'
# response_column='Species_Iris_setosa'
# predictor_columns='PetalLengthCm,SepalLengthCm'
# iteration_count: 6
# rejected_row_count: 0
# accepted_row_count: 150

# %% [markdown]
# ##### <font color='#555555'>SVM with three features<font>

# %%
from vertica_ml_python import svm_classifier
drop_model("svm_iris",cur)
svm_iris=svm_classifier(model_name="svm_iris",input_relation="iris_temp",response_column="Species_Iris_setosa",
                   predictor_columns=["PetalLengthCm","SepalLengthCm","PetalWidthCm"],cursor=cur)
svm_iris.plot()
# Out:
# The model svm_iris was successfully dropped.

# %% [markdown]
# ##### <font color='#555555'>SVM with four features<font>

# %%
from vertica_ml_python import svm_classifier
drop_model("svm_iris",cur)
svm_iris=svm_classifier(model_name="svm_iris",input_relation="iris_temp",response_column="Species_Iris_setosa",
                   predictor_columns=["PetalLengthCm","SepalLengthCm","PetalWidthCm","SepalWidthCm"],cursor=cur)
svm_iris
# Out:
# The model svm_iris was successfully dropped.
# <table style="border-collapse: collapse; border: 2px solid rgb(200,200,200)"><tr style="{border: 1px solid rgb(200,200,200);}"><td style="border-bottom: 1px solid #DDD;font-size:1.02em;background-color:#DDD"><b></b></td><td style="font-size:1.02em;background-color:#DDD"><b>coefficient</b></td></tr><tr style="{border: 1px solid rgb(200,200,200);}"><td style="border-bottom: 1px solid #DDD;font-size:1.02em;background-color:#DDD"><b>Intercept</b></td><td style="border: 1px solid rgb(200,200,200);">0.0931563016679742</td></tr><tr style="{border: 1px solid rgb(200,200,200);}"><td style="border-bottom: 1px solid #DDD;font-size:1.02em;background-color:#DDD"><b>petallengthcm</b></td><td style="border: 1px solid rgb(200,200,200);">-0.793729418803655</td></tr><tr style="{border: 1px solid rgb(200,200,200);}"><td style="border-bottom: 1px solid #DDD;font-size:1.02em;background-color:#DDD"><b>sepallengthcm</b></td><td style="border: 1px solid rgb(200,200,200);">0.145248138440046</td></tr><tr style="{border: 1px solid rgb(200,200,200);}"><td style="border-bottom: 1px solid #DDD;font-size:1.02em;background-color:#DDD"><b>petalwidthcm</b></td><td style="border: 1px solid rgb(200,200,200);">-0.374529786870006</td></tr><tr style="{border: 1px solid rgb(200,200,200);}"><td style="border-bottom: 1px solid #DDD;font-size:1.02em;background-color:#DDD"><b>sepalwidthcm</b></td><td style="border: 1px solid rgb(200,200,200);">0.496642336015163</td></tr></table>
# model_type='svm_classifier'
# model_name='svm_iris'
# input_relation='iris_temp'
# response_column='Species_Iris_setosa'
# predictor_columns='PetalLengthCm,SepalLengthCm,PetalWidthCm,SepalWidthCm'
# iteration_count: 5
# rejected_row_count: 0
# accepted_row_count: 150

# %% [markdown]
# For this model, we can not plot the hyperplan (sorry I do not know the fourth dimension) but we wan see the importance of each feature.

# %%
svm_iris.features_importance()
# Out:
# <table style="border-collapse: collapse; border: 2px solid rgb(200,200,200)"><tr style="{border: 1px solid rgb(200,200,200);}"><td style="border-bottom: 1px solid #DDD;font-size:1.02em;background-color:#DDD"><b></b></td><td style="font-size:1.02em;background-color:#DDD"><b>Importance</b></td></tr><tr style="{border: 1px solid rgb(200,200,200);}"><td style="border-bottom: 1px solid #DDD;font-size:1.02em;background-color:#DDD"><b>sepallengthcm</b></td><td style="border: 1px solid rgb(200,200,200);">0.05948571176665842</td></tr><tr style="{border: 1px solid rgb(200,200,200);}"><td style="border-bottom: 1px solid #DDD;font-size:1.02em;background-color:#DDD"><b>sepalwidthcm</b></td><td style="border: 1px solid rgb(200,200,200);">0.10650362282443895</td></tr><tr style="{border: 1px solid rgb(200,200,200);}"><td style="border-bottom: 1px solid #DDD;font-size:1.02em;background-color:#DDD"><b>petalwidthcm</b></td><td style="border: 1px solid rgb(200,200,200);">0.14136420400407973</td></tr><tr style="{border: 1px solid rgb(200,200,200);}"><td style="border-bottom: 1px solid #DDD;font-size:1.02em;background-color:#DDD"><b>petallengthcm</b></td><td style="border: 1px solid rgb(200,200,200);">0.6926464614048229</td></tr></table>

# %% [markdown]
# As expected the Petal Length is very important. Let's see the model accuracy.

# %%
svm_iris.error_rate()
# Out:
# <table style="border-collapse: collapse; border: 2px solid rgb(200,200,200)"><tr style="{border: 1px solid rgb(200,200,200);}"><td style="border-bottom: 1px solid #DDD;font-size:1.02em;background-color:#DDD"><b></b></td><td style="font-size:1.02em;background-color:#DDD"><b>error_rate</b></td></tr><tr style="{border: 1px solid rgb(200,200,200);}"><td style="border-bottom: 1px solid #DDD;font-size:1.02em;background-color:#DDD"><b>0</b></td><td style="border: 1px solid rgb(200,200,200);">0.0</td></tr><tr style="{border: 1px solid rgb(200,200,200);}"><td style="border-bottom: 1px solid #DDD;font-size:1.02em;background-color:#DDD"><b>1</b></td><td style="border: 1px solid rgb(200,200,200);">0.0</td></tr><tr style="{border: 1px solid rgb(200,200,200);}"><td style="border-bottom: 1px solid #DDD;font-size:1.02em;background-color:#DDD"><b>total</b></td><td style="border: 1px solid rgb(200,200,200);">0.0</td></tr></table>

# %% [markdown]
# We can see that no matter the number of variables, we have an accuracy of 100%. Besides, we can see the hyperplan separating all the data perfectly. For this dataset, we can build a very easy model with only the Petal Length variable to predict if the specie is Iris Setosa. We can now try to see how to evaluate the others.

# %% [markdown]
# #### <font color='#666666'>SVM Classification on the two other species<font>
# We must delete the Iris Setosa from our RVD.

# %%
iris=RVD('Iris',cur)
iris["Species"].decode(["Iris-setosa","Iris-versicolor"],[None,0],1)
iris["Species"].dropna()
iris["Species"].convert_to_num()
# Out:
# 50 elements were dropped

# %% [markdown]
# We can now save our RVD.

# %%
drop_view("iris_temp",cur)
iris.save("iris_temp")
# Out:
# The view iris_temp was successfully dropped.
# The RVD was successfully saved.

# %% [markdown]
# Let's now build our model.

# %%
from vertica_ml_python import svm_classifier
drop_model("svm_iris",cur)
svm_iris=svm_classifier(model_name="svm_iris",input_relation="iris_temp",response_column="Species",
                   predictor_columns=["PetalLengthCm","SepalLengthCm","PetalWidthCm","SepalWidthCm"],cursor=cur)
print(svm_iris)
# Out:
# The model svm_iris was successfully dropped.
# <table style="border-collapse: collapse; border: 2px solid rgb(200,200,200)"><tr style="{border: 1px solid rgb(200,200,200);}"><td style="border-bottom: 1px solid #DDD;font-size:1.02em;background-color:#DDD"><b></b></td><td style="font-size:1.02em;background-color:#DDD"><b>coefficient</b></td></tr><tr style="{border: 1px solid rgb(200,200,200);}"><td style="border-bottom: 1px solid #DDD;font-size:1.02em;background-color:#DDD"><b>Intercept</b></td><td style="border: 1px solid rgb(200,200,200);">-1.71153221376208</td></tr><tr style="{border: 1px solid rgb(200,200,200);}"><td style="border-bottom: 1px solid #DDD;font-size:1.02em;background-color:#DDD"><b>petallengthcm</b></td><td style="border: 1px solid rgb(200,200,200);">1.38128764635026</td></tr><tr style="{border: 1px solid rgb(200,200,200);}"><td style="border-bottom: 1px solid #DDD;font-size:1.02em;background-color:#DDD"><b>sepallengthcm</b></td><td style="border: 1px solid rgb(200,200,200);">-0.850962938050926</td></tr><tr style="{border: 1px solid rgb(200,200,200);}"><td style="border-bottom: 1px solid #DDD;font-size:1.02em;background-color:#DDD"><b>petalwidthcm</b></td><td style="border: 1px solid rgb(200,200,200);">1.86448405980504</td></tr><tr style="{border: 1px solid rgb(200,200,200);}"><td style="border-bottom: 1px solid #DDD;font-size:1.02em;background-color:#DDD"><b>sepalwidthcm</b></td><td style="border: 1px solid rgb(200,200,200);">-0.985559931548558</td></tr></table>
# model_type='svm_classifier'
# model_name='svm_iris'
# input_relation='iris_temp'
# response_column='Species'
# predictor_columns='PetalLengthCm,SepalLengthCm,PetalWidthCm,SepalWidthCm'
# iteration_count: 6
# rejected_row_count: 0
# accepted_row_count: 100

# %%
svm_iris.features_importance()
# Out:
# <table style="border-collapse: collapse; border: 2px solid rgb(200,200,200)"><tr style="{border: 1px solid rgb(200,200,200);}"><td style="border-bottom: 1px solid #DDD;font-size:1.02em;background-color:#DDD"><b></b></td><td style="font-size:1.02em;background-color:#DDD"><b>Importance</b></td></tr><tr style="{border: 1px solid rgb(200,200,200);}"><td style="border-bottom: 1px solid #DDD;font-size:1.02em;background-color:#DDD"><b>sepalwidthcm</b></td><td style="border: 1px solid rgb(200,200,200);">0.11611467875917439</td></tr><tr style="{border: 1px solid rgb(200,200,200);}"><td style="border-bottom: 1px solid #DDD;font-size:1.02em;background-color:#DDD"><b>sepallengthcm</b></td><td style="border: 1px solid rgb(200,200,200);">0.19971027971236793</td></tr><tr style="{border: 1px solid rgb(200,200,200);}"><td style="border-bottom: 1px solid #DDD;font-size:1.02em;background-color:#DDD"><b>petalwidthcm</b></td><td style="border: 1px solid rgb(200,200,200);">0.2804114164648016</td></tr><tr style="{border: 1px solid rgb(200,200,200);}"><td style="border-bottom: 1px solid #DDD;font-size:1.02em;background-color:#DDD"><b>petallengthcm</b></td><td style="border: 1px solid rgb(200,200,200);">0.4037636250636561</td></tr></table>

# %%
svm_iris.roc()
# Out:
# <table style="border-collapse: collapse; border: 2px solid rgb(200,200,200)"><tr style="{border: 1px solid rgb(200,200,200);}"><td style="border-bottom: 1px solid #DDD;font-size:1.02em;background-color:#DDD"><b></b></td><td style="font-size:1.02em;background-color:#DDD"><b>value</b></td></tr><tr style="{border: 1px solid rgb(200,200,200);}"><td style="border-bottom: 1px solid #DDD;font-size:1.02em;background-color:#DDD"><b>auc</b></td><td style="border: 1px solid rgb(200,200,200);">0.97</td></tr></table>
# <table style="border-collapse: collapse; border: 2px solid rgb(200,200,200)"><tr style="{border: 1px solid rgb(200,200,200);}"><td style="border-bottom: 1px solid #DDD;font-size:1.02em;background-color:#DDD"><b></b></td><td style="font-size:1.02em;background-color:#DDD"><b>threshold</b></td><td style="font-size:1.02em;background-color:#DDD"><b>false_positive</b></td><td style="font-size:1.02em;background-color:#DDD"><b>true_positive</b></td></tr><tr style="{border: 1px solid rgb(200,200,200);}"><td style="border-bottom: 1px solid #DDD;font-size:1.02em;background-color:#DDD"><b>0</b></td><td style="border: 1px solid rgb(200,200,200);">0.0</td><td style="border: 1px solid rgb(200,200,200);">1.0</td><td style="border: 1px solid rgb(200,200,200);">1.0</td></tr><tr style="{border: 1px solid rgb(200,200,200);}"><td style="border-bottom: 1px solid #DDD;font-size:1.02em;background-color:#DDD"><b>1</b></td><td style="border: 1px solid rgb(200,200,200);">0.25</td><td style="border: 1px solid rgb(200,200,200);">0.06</td><td style="border: 1px solid rgb(200,200,200);">1.0</td></tr><tr style="{border: 1px solid rgb(200,200,200);}"><td style="border-bottom: 1px solid #DDD;font-size:1.02em;background-color:#DDD"><b>2</b></td><td style="border: 1px solid rgb(200,200,200);">0.5</td><td style="border: 1px solid rgb(200,200,200);">0.06</td><td style="border: 1px solid rgb(200,200,200);">1.0</td></tr><tr style="{border: 1px solid rgb(200,200,200);}"><td style="border-bottom: 1px solid #DDD;font-size:1.02em;background-color:#DDD"><b>3</b></td><td style="border: 1px solid rgb(200,200,200);">0.75</td><td style="border: 1px solid rgb(200,200,200);">0.06</td><td style="border: 1px solid rgb(200,200,200);">1.0</td></tr><tr style="{border: 1px solid rgb(200,200,200);}"><td style="border-bottom: 1px solid #DDD;font-size:1.02em;background-color:#DDD"><b>4</b></td><td style="border: 1px solid rgb(200,200,200);">1.0</td><td style="border: 1px solid rgb(200,200,200);">0.0</td><td style="border: 1px solid rgb(200,200,200);">0.0</td></tr></table>
# (<column_matrix>, <column_matrix>)

# %%
svm_iris.confusion_matrix()
# Out:
# <table style="border-collapse: collapse; border: 2px solid rgb(200,200,200)"><tr style="{border: 1px solid rgb(200,200,200);}"><td style="border-bottom: 1px solid #DDD;font-size:1.02em;background-color:#DDD"><b></b></td><td style="font-size:1.02em;background-color:#DDD"><b>0</b></td><td style="font-size:1.02em;background-color:#DDD"><b>1</b></td></tr><tr style="{border: 1px solid rgb(200,200,200);}"><td style="border-bottom: 1px solid #DDD;font-size:1.02em;background-color:#DDD"><b>0</b></td><td style="border: 1px solid rgb(200,200,200);">47</td><td style="border: 1px solid rgb(200,200,200);">3</td></tr><tr style="{border: 1px solid rgb(200,200,200);}"><td style="border-bottom: 1px solid #DDD;font-size:1.02em;background-color:#DDD"><b>1</b></td><td style="border: 1px solid rgb(200,200,200);">0</td><td style="border: 1px solid rgb(200,200,200);">50</td></tr></table>

# %%
svm_iris.error_rate()
# Out:
# <table style="border-collapse: collapse; border: 2px solid rgb(200,200,200)"><tr style="{border: 1px solid rgb(200,200,200);}"><td style="border-bottom: 1px solid #DDD;font-size:1.02em;background-color:#DDD"><b></b></td><td style="font-size:1.02em;background-color:#DDD"><b>error_rate</b></td></tr><tr style="{border: 1px solid rgb(200,200,200);}"><td style="border-bottom: 1px solid #DDD;font-size:1.02em;background-color:#DDD"><b>0</b></td><td style="border: 1px solid rgb(200,200,200);">0.06</td></tr><tr style="{border: 1px solid rgb(200,200,200);}"><td style="border-bottom: 1px solid #DDD;font-size:1.02em;background-color:#DDD"><b>1</b></td><td style="border: 1px solid rgb(200,200,200);">0.0</td></tr><tr style="{border: 1px solid rgb(200,200,200);}"><td style="border-bottom: 1px solid #DDD;font-size:1.02em;background-color:#DDD"><b>total</b></td><td style="border: 1px solid rgb(200,200,200);">0.03</td></tr></table>

# %% [markdown]
# Wow! We built a model with 97% of accuracy. Combining the two models we have at least 98% of good predictions.
#
# ### <font color='#555555'>Conclusion<font>
#
# Building multiple binomial models can be more efficient than clustering or a multinomial model if we understand our dataset. At the end doing everything using the power of Vertica can be easy and very efficient by using Vertica ML Python.
#
# ### <font color='#1e90ff'>About me<font>
#
# <br>
#
# <div style="float:right;margin-left:30px;"><img src="images/about.png" width="520px"></div>
#
# <div style="text-align:justify;">My name is Badr. I'm a young datascientist working with the best company ever. Vertica is for me the futur of big data. I'm passionate about mathematics and computer science and specially about datascience which allies both. I like learning from others and teaching what I know.<br><br>
# <img src="images/vpython.png" width="200px">
# </div>

# %% [markdown]
# ### <font color='#1e90ff'>To contact me<font>
# <b>@: </b><a href="mailto:badr.ouali@microfocus.com">badr.ouali@microfocus.com</a><br>
# <b>In: </b><a href="https://www.linkedin.com/in/badr-ouali/">badr-ouali</a>
