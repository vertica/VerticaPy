# %% [markdown]
# # vDataFrame.to_vdf

# %%
vDataFrame.to_vdf(name: str)

# %% [markdown]
# Saves the vDataFrame to a .vdf text file. The saving can be loaded using the 'read_vdf' function.
#
# ### Parameters
#
# <table id="parameters">
#     <tr> <th>Name</th> <th>Type</th> <th>Optional</th> <th>Description</th> </tr>
#     <tr> <td><div class="param_name">name</div></td> <td><div class="type">str</div></td> <td><div class = "no">&#10060;</div></td> <td>Name of the VDF file. Be careful: if a VDF file with the same name exists, it will over-write it.</td> </tr>
# </table>

# %% [markdown]
# ### Returns
#
# <b>vDataFrame</b> : self
#
# ### Example

# %%
from vertica_ml_python.learn.datasets import load_titanic
titanic = load_titanic()
print(titanic)
# Out:
# <table style="border-collapse: collapse; border: 2px solid white"><tr style="{border: 1px solid white;}"><td style="border-bottom: 1px solid #DDD;font-size:1.02em;background-color:#263133;color:white"><b></b></td><td style="font-size:1.02em;background-color:#263133;color:white"><b>survived</b></td><td style="font-size:1.02em;background-color:#263133;color:white"><b>boat</b></td><td style="font-size:1.02em;background-color:#263133;color:white"><b>ticket</b></td><td style="font-size:1.02em;background-color:#263133;color:white"><b>embarked</b></td><td style="font-size:1.02em;background-color:#263133;color:white"><b>home.dest</b></td><td style="font-size:1.02em;background-color:#263133;color:white"><b>sibsp</b></td><td style="font-size:1.02em;background-color:#263133;color:white"><b>fare</b></td><td style="font-size:1.02em;background-color:#263133;color:white"><b>sex</b></td><td style="font-size:1.02em;background-color:#263133;color:white"><b>body</b></td><td style="font-size:1.02em;background-color:#263133;color:white"><b>pclass</b></td><td style="font-size:1.02em;background-color:#263133;color:white"><b>age</b></td><td style="font-size:1.02em;background-color:#263133;color:white"><b>name</b></td><td style="font-size:1.02em;background-color:#263133;color:white"><b>cabin</b></td><td style="font-size:1.02em;background-color:#263133;color:white"><b>parch</b></td></tr><tr style="{border: 1px solid white;}"><td style="border-bottom: 1px solid #DDD;font-size:1.02em;background-color:#263133;color:white"><b>0</b></td><td style="border: 1px solid white;">0</td><td style="border: 1px solid white;">None</td><td style="border: 1px solid white;">113781</td><td style="border: 1px solid white;">S</td><td style="border: 1px solid white;">Montreal, PQ / Chesterville, ON</td><td style="border: 1px solid white;">1</td><td style="border: 1px solid white;">151.55000</td><td style="border: 1px solid white;">female</td><td style="border: 1px solid white;">None</td><td style="border: 1px solid white;">1</td><td style="border: 1px solid white;">2.000</td><td style="border: 1px solid white;">Allison, Miss. Helen Loraine</td><td style="border: 1px solid white;">C22 C26</td><td style="border: 1px solid white;">2</td></tr><tr style="{border: 1px solid white;}"><td style="border-bottom: 1px solid #DDD;font-size:1.02em;background-color:#263133;color:white"><b>1</b></td><td style="border: 1px solid white;">0</td><td style="border: 1px solid white;">None</td><td style="border: 1px solid white;">113781</td><td style="border: 1px solid white;">S</td><td style="border: 1px solid white;">Montreal, PQ / Chesterville, ON</td><td style="border: 1px solid white;">1</td><td style="border: 1px solid white;">151.55000</td><td style="border: 1px solid white;">male</td><td style="border: 1px solid white;">135</td><td style="border: 1px solid white;">1</td><td style="border: 1px solid white;">30.000</td><td style="border: 1px solid white;">Allison, Mr. Hudson Joshua Creighton</td><td style="border: 1px solid white;">C22 C26</td><td style="border: 1px solid white;">2</td></tr><tr style="{border: 1px solid white;}"><td style="border-bottom: 1px solid #DDD;font-size:1.02em;background-color:#263133;color:white"><b>2</b></td><td style="border: 1px solid white;">0</td><td style="border: 1px solid white;">None</td><td style="border: 1px solid white;">113781</td><td style="border: 1px solid white;">S</td><td style="border: 1px solid white;">Montreal, PQ / Chesterville, ON</td><td style="border: 1px solid white;">1</td><td style="border: 1px solid white;">151.55000</td><td style="border: 1px solid white;">female</td><td style="border: 1px solid white;">None</td><td style="border: 1px solid white;">1</td><td style="border: 1px solid white;">25.000</td><td style="border: 1px solid white;">Allison, Mrs. Hudson J C (Bessie Waldo Daniels)</td><td style="border: 1px solid white;">C22 C26</td><td style="border: 1px solid white;">2</td></tr><tr style="{border: 1px solid white;}"><td style="bo ...
# <object>  Name: titanic, Number of rows: 1234, Number of columns: 14

# %%
# Doing some transformations
titanic.get_dummies()
titanic.normalize()
# Out:
# <table style="border-collapse: collapse; border: 2px solid white"><tr style="{border: 1px solid white;}"><td style="border-bottom: 1px solid #DDD;font-size:1.02em;background-color:#263133;color:white"><b></b></td><td style="font-size:1.02em;background-color:#263133;color:white"><b>survived</b></td><td style="font-size:1.02em;background-color:#263133;color:white"><b>boat</b></td><td style="font-size:1.02em;background-color:#263133;color:white"><b>ticket</b></td><td style="font-size:1.02em;background-color:#263133;color:white"><b>embarked</b></td><td style="font-size:1.02em;background-color:#263133;color:white"><b>home.dest</b></td><td style="font-size:1.02em;background-color:#263133;color:white"><b>sibsp</b></td><td style="font-size:1.02em;background-color:#263133;color:white"><b>fare</b></td><td style="font-size:1.02em;background-color:#263133;color:white"><b>sex</b></td><td style="font-size:1.02em;background-color:#263133;color:white"><b>body</b></td><td style="font-size:1.02em;background-color:#263133;color:white"><b>pclass</b></td><td style="font-size:1.02em;background-color:#263133;color:white"><b>age</b></td><td style="font-size:1.02em;background-color:#263133;color:white"><b>name</b></td><td style="font-size:1.02em;background-color:#263133;color:white"><b>cabin</b></td><td style="font-size:1.02em;background-color:#263133;color:white"><b>parch</b></td><td style="font-size:1.02em;background-color:#263133;color:white"><b>embarked_C</b></td><td style="font-size:1.02em;background-color:#263133;color:white"><b>embarked_Q</b></td><td style="font-size:1.02em;background-color:#263133;color:white"><b>sibsp_0</b></td><td style="font-size:1.02em;background-color:#263133;color:white"><b>sibsp_1</b></td><td style="font-size:1.02em;background-color:#263133;color:white"><b>sibsp_2</b></td><td style="font-size:1.02em;background-color:#263133;color:white"><b>sibsp_3</b></td><td style="font-size:1.02em;background-color:#263133;color:white"><b>sibsp_4</b></td><td style="font-size:1.02em;background-color:#263133;color:white"><b>sibsp_5</b></td><td style="font-size:1.02em;background-color:#263133;color:white"><b>sex_female</b></td><td style="font-size:1.02em;background-color:#263133;color:white"><b>pclass_1</b></td><td style="font-size:1.02em;background-color:#263133;color:white"><b>pclass_2</b></td><td style="font-size:1.02em;background-color:#263133;color:white"><b>parch_0</b></td><td style="font-size:1.02em;background-color:#263133;color:white"><b>parch_1</b></td><td style="font-size:1.02em;background-color:#263133;color:white"><b>parch_2</b></td><td style="font-size:1.02em;background-color:#263133;color:white"><b>parch_3</b></td><td style="font-size:1.02em;background-color:#263133;color:white"><b>parch_4</b></td><td style="font-size:1.02em;background-color:#263133;color:white"><b>parch_5</b></td><td style="font-size:1.02em;background-color:#263133;color:white"><b>parch_6</b></td></tr><tr style="{border: 1px solid white;}"><td style="border-bottom: 1px solid #DDD;font-size:1.02em;background-color:#263133;color:white"><b>0</b></td><td style="border: 1px solid white;">-0.757307371153963162979989569746</td><td style="border: 1px solid white;">None</td><td style="border: 1px solid white;">113781</td><td style="border: 1px solid white;">S</td><td style="border: 1px solid white;">Montreal, PQ / Chesterville, ON</td><td style="border: 1px solid white;">0.476361452530317344428951316723</td><td style="border: 1px solid white;">2.2335228377568673306163744003</td><td style="border: 1px solid white;">female</td><td style="border: 1px solid white;">None</td><td style="border: 1px solid white;">-1.52458485653939825566284767748</td><td style="border: 1px solid white;">-1.9502503129565278908367342155</td><td style="border: 1px solid white;">Allison, Miss. Helen Loraine</td><td style="border: 1px solid white;">C22 C26</td><td style="border: 1px solid white;">1.866851401077760435621662793693</td><td style="border: 1px solid white;">-0.5076328463726798817790 ...
# <object>  Name: titanic, Number of rows: 1234, Number of columns: 32

# %%
# Creating the VDF file of the current vDataFrame
titanic.to_vdf(name = "titanic")
# Out:
# <table style="border-collapse: collapse; border: 2px solid white"><tr style="{border: 1px solid white;}"><td style="border-bottom: 1px solid #DDD;font-size:1.02em;background-color:#263133;color:white"><b></b></td><td style="font-size:1.02em;background-color:#263133;color:white"><b>survived</b></td><td style="font-size:1.02em;background-color:#263133;color:white"><b>boat</b></td><td style="font-size:1.02em;background-color:#263133;color:white"><b>ticket</b></td><td style="font-size:1.02em;background-color:#263133;color:white"><b>embarked</b></td><td style="font-size:1.02em;background-color:#263133;color:white"><b>home.dest</b></td><td style="font-size:1.02em;background-color:#263133;color:white"><b>sibsp</b></td><td style="font-size:1.02em;background-color:#263133;color:white"><b>fare</b></td><td style="font-size:1.02em;background-color:#263133;color:white"><b>sex</b></td><td style="font-size:1.02em;background-color:#263133;color:white"><b>body</b></td><td style="font-size:1.02em;background-color:#263133;color:white"><b>pclass</b></td><td style="font-size:1.02em;background-color:#263133;color:white"><b>age</b></td><td style="font-size:1.02em;background-color:#263133;color:white"><b>name</b></td><td style="font-size:1.02em;background-color:#263133;color:white"><b>cabin</b></td><td style="font-size:1.02em;background-color:#263133;color:white"><b>parch</b></td><td style="font-size:1.02em;background-color:#263133;color:white"><b>embarked_C</b></td><td style="font-size:1.02em;background-color:#263133;color:white"><b>embarked_Q</b></td><td style="font-size:1.02em;background-color:#263133;color:white"><b>sibsp_0</b></td><td style="font-size:1.02em;background-color:#263133;color:white"><b>sibsp_1</b></td><td style="font-size:1.02em;background-color:#263133;color:white"><b>sibsp_2</b></td><td style="font-size:1.02em;background-color:#263133;color:white"><b>sibsp_3</b></td><td style="font-size:1.02em;background-color:#263133;color:white"><b>sibsp_4</b></td><td style="font-size:1.02em;background-color:#263133;color:white"><b>sibsp_5</b></td><td style="font-size:1.02em;background-color:#263133;color:white"><b>sex_female</b></td><td style="font-size:1.02em;background-color:#263133;color:white"><b>pclass_1</b></td><td style="font-size:1.02em;background-color:#263133;color:white"><b>pclass_2</b></td><td style="font-size:1.02em;background-color:#263133;color:white"><b>parch_0</b></td><td style="font-size:1.02em;background-color:#263133;color:white"><b>parch_1</b></td><td style="font-size:1.02em;background-color:#263133;color:white"><b>parch_2</b></td><td style="font-size:1.02em;background-color:#263133;color:white"><b>parch_3</b></td><td style="font-size:1.02em;background-color:#263133;color:white"><b>parch_4</b></td><td style="font-size:1.02em;background-color:#263133;color:white"><b>parch_5</b></td><td style="font-size:1.02em;background-color:#263133;color:white"><b>parch_6</b></td></tr><tr style="{border: 1px solid white;}"><td style="border-bottom: 1px solid #DDD;font-size:1.02em;background-color:#263133;color:white"><b>0</b></td><td style="border: 1px solid white;">-0.757307371153963162979989569746</td><td style="border: 1px solid white;">None</td><td style="border: 1px solid white;">113781</td><td style="border: 1px solid white;">S</td><td style="border: 1px solid white;">Montreal, PQ / Chesterville, ON</td><td style="border: 1px solid white;">0.476361452530317344428951316723</td><td style="border: 1px solid white;">2.2335228377568673306163744003</td><td style="border: 1px solid white;">female</td><td style="border: 1px solid white;">None</td><td style="border: 1px solid white;">-1.52458485653939825566284767748</td><td style="border: 1px solid white;">-1.9502503129565278908367342155</td><td style="border: 1px solid white;">Allison, Miss. Helen Loraine</td><td style="border: 1px solid white;">C22 C26</td><td style="border: 1px solid white;">1.866851401077760435621662793693</td><td style="border: 1px solid white;">-0.5076328463726798817790 ...
# <object>  Name: titanic, Number of rows: 1234, Number of columns: 32

# %%
# Reading the VDF file
file = open("titanic.vdf", "r")
print("It will save everything needed to recreate the vDataFrame:\n")
print(''.join(file.readlines()))
file.close()
# Out:
# It will save everything needed to recreate the vDataFrame:
#
# vdf_save = vDataFrame("", empty = True)
# vdf_save._VERTICA_ML_PYTHON_VARIABLES_["dsn"] = ''
# vdf_save._VERTICA_ML_PYTHON_VARIABLES_["input_relation"] = 'titanic'
# vdf_save._VERTICA_ML_PYTHON_VARIABLES_["main_relation"] = '"public"."titanic"'
# vdf_save._VERTICA_ML_PYTHON_VARIABLES_["schema"] = 'public'
# vdf_save._VERTICA_ML_PYTHON_VARIABLES_["columns"] = ['"survived"', '"boat"', '"ticket"', '"embarked"', '"home.dest"', '"sibsp"', '"fare"', '"sex"', '"body"', '"pclass"', '"age"', '"name"', '"cabin"', '"parch"', '"embarked_C"', '"embarked_Q"', '"sibsp_0"', '"sibsp_1"', '"sibsp_2"', '"sibsp_3"', '"sibsp_4"', '"sibsp_5"', '"sex_female"', '"pclass_1"', '"pclass_2"', '"parch_0"', '"parch_1"', '"parch_2"', '"parch_3"', '"parch_4"', '"parch_5"', '"parch_6"']
# vdf_save._VERTICA_ML_PYTHON_VARIABLES_["exclude_columns"] = []
# vdf_save._VERTICA_ML_PYTHON_VARIABLES_["where"] = []
# vdf_save._VERTICA_ML_PYTHON_VARIABLES_["query_on"] = False
# vdf_save._VERTICA_ML_PYTHON_VARIABLES_["time_on"] = False
# vdf_save._VERTICA_ML_PYTHON_VARIABLES_["order_by"] = {}
# vdf_save._VERTICA_ML_PYTHON_VARIABLES_["history"] = ['{Mon Apr 27 19:17:48 2020} [Get Dummies]: One hot encoder was applied to the vcolumn "embarked"\n2 feature(s) was/were created: "embarked_C", "embarked_Q".', '{Mon Apr 27 19:17:48 2020} [Get Dummies]: One hot encoder was applied to the vcolumn "sibsp"\n6 feature(s) was/were created: "sibsp_0", "sibsp_1", "sibsp_2", "sibsp_3", "sibsp_4", "sibsp_5".', '{Mon Apr 27 19:17:48 2020} [Get Dummies]: One hot encoder was applied to the vcolumn "sex"\n1 feature(s) was/were created: "sex_female".', '{Mon Apr 27 19:17:48 2020} [Get Dummies]: One hot encoder was applied to the vcolumn "pclass"\n2 feature(s) was/were created: "pclass_1", "pclass_2".', '{Mon Apr 27 19:17:48 2020} [Get Dummies]: One hot encoder was applied to the vcolumn "parch"\n7 feature(s) was/were created: "parch_0", "parch_1", "parch_2", "parch_3", "parch_4", "parch_5", "parch_6".', '{Mon Apr 27 19:17:48 2020} [Normalize]: The vcolumn \'"survived"\' was normalized with the method \'zscore\'.', '{Mon Apr 27 19:17:48 2020} [Normalize]: The vcolumn \'"sibsp"\' was normalized with the method \'zscore\'.', '{Mon Apr 27 19:17:48 2020} [Normalize]: The vcolumn \'"fare"\' was normalized with the method \'zscore\'.', '{Mon Apr 27 19:17:48 2020} [Normalize]: The vcolumn \'"body"\' was normalized with the method \'zscore\'.', '{Mon Apr 27 19:17:48 2020} [Normalize]: The vcolumn \'"pclass"\' was normalized with the method \'zscore\'.', '{Mon Apr 27 19:17:48 2020} [Normalize]: The vcolumn \'"age"\' was normalized with the method \'zscore\'.', '{Mon Apr 27 19:17:48 2020} [Normalize]: The vcolumn \'"parch"\' was normalized with the method \'zscore\'.', '{Mon Apr 27 19:17:48 2020} [Normalize]: The vcolumn \'"embarked_C"\' was normalized with the method \'zscore\'.', '{Mon Apr 27 19:17:48 2020} [Normalize]: The vcolumn \'"embarked_Q"\' was normalized with the method \'zscore\'.', '{Mon Apr 27 19:17:48 2020} [Normalize]: The vcolumn \'"sibsp_0"\' was normalized with the method \'zscore\'.', '{Mon Apr 27 19:17:48 2020} [Normalize]: The vcolumn \'"sibsp_1"\' was normalized with the method \'zscore\'.', '{Mon Apr 27 19:17:48 2020} [Normalize]: The vcolumn \'"sibsp_2"\' was normalized with the method \'zscore\'.', '{Mon Apr 27 19:17:48 2020} [Normalize]: The vcolumn \'"sibsp_3"\' was normalized with the method \'zscore\'.', '{Mon Apr 27 19:17:48 2020} [Normalize]: The vcolumn \'"sibsp_4"\' was normalized with the method \'zscore\'.', '{Mon Apr 27 19:17:48 2020} [Normalize]: The vcolumn \'"sibsp_5"\' was normalized with the method \'zscore\'.', '{Mon Apr 27 19:17:48 2020} [Normalize]: The vcolumn \'"sex_female"\' was normalized with the method \'zscore\'.', '{Mon Apr 27 19:17:48 2020} [Normalize]: The vcolumn \'"pclass_1"\' was normalized with the method \'zscore\'.', '{Mon Apr 27 19:17:48 2020} [Normalize]: The vcolumn \'"pclass_2"\' was normalized with the method \'zscore\'.', '{Mon Apr 27 19:17:48 2020} [Normalize]: The vcolumn \'"parch_0"\' was normalized with the method \'zscore\'.', '{Mon Apr 27 19:17:48 2020} [Normalize]: The vcolumn \'"parch_1"\' was normalized with the method \'zscore\'.', '{Mon Apr 27 19:17:48 2020} [Normalize]: The vcolumn \'"parch_2"\' was normalized with the method \'zscore\'.', '{Mon Apr 27 19:17:48 2020} [Normalize]: The vcolumn \'"parch_3"\' was normalized with the method \'zscore\'.', '{Mon Apr 27 19:17:48 2020} [Normalize]: The vcolumn \'"parch_4"\' was normalized with the method \'zscore\'.', '{Mon Apr 27 19:17:48 2020} [Normalize]: The vcolumn \'"parch_5"\' was normalized with the method \'zscore\'.', '{Mon Apr 27 19:17:48 2020} [Normalize]: The vcolumn \'"parch_6"\' was normalized with the method \'zscore\'.']
# vdf_save._VERTICA_ML_PYTHON_VARIABLES_["saving"] = []
# vdf_save._VERTICA_ML_PYTHON_VARIABLES_["schema_writing"] = ''
# save_vColumn = vColumn('"survived"', parent = vdf_save, transformations = [('"survived"', 'int', 'int'), ('({} - 0.364667747163695) / (0.481532018641288)', 'float', 'float')], catalog = {'cov': {}, 'pearson': {}, 'spearman': {}, 'kendall': {}, 'cramer': {}, 'biserial': {}, 'regr_avgx': {}, 'regr_avgy': {}, 'regr_count': {}, 'regr_intercept': {}, 'regr_r2': {}, 'regr_slope': {}, 'regr_sxx': {}, 'regr_sxy': {}, 'regr_syy': {}, 'mean': 0, 'std': 1})
# setattr(vdf_save, '"survived"', save_vColumn)
# setattr(vdf_save, 'survived', save_vColumn)
# save_vColumn = vColumn('"boat"', parent = vdf_save, transformations = [('"boat"', 'varchar(100)', 'text')], catalog = {'cov': {}, 'pearson': {}, 'spearman': {}, 'kendall': {}, 'cramer': {}, 'biserial': {}, 'regr_avgx': {}, 'regr_avgy': {}, 'regr_count': {}, 'regr_intercept': {}, 'regr_r2': {}, 'regr_slope': {}, 'regr_sxx': {}, 'regr_sxy': {}, 'regr_syy': {}, 'approx_unique': 26})
# setattr(vdf_save, '"boat"', save_vColumn)
# setattr(vdf_save, 'boat', save_vColumn)
# save_vColumn = vColumn('"ticket"', parent = vdf_save, transformations = [('"ticket"', 'varchar(36)', 'text')], catalog = {'cov': {}, 'pearson': {}, 'spearman': {}, 'kendall': {}, 'cramer': {}, 'biserial': {}, 'regr_avgx': {}, 'regr_avgy': {}, 'regr_count': {}, 'regr_intercept': {}, 'regr_r2': {}, 'regr_slope': {}, 'regr_sxx': {}, 'regr_sxy': {}, 'regr_syy': {}, 'approx_unique': 888})
# setattr(vdf_save, '"ticket"', save_vColumn)
# setattr(vdf_save, 'ticket', save_vColumn)
# save_vColumn = vColumn('"embarked"', parent = vdf_save, transformations = [('"embarked"', 'varchar(20)', 'text')], catalog = {'cov': {}, 'pearson': {}, 'spearman': {}, 'kendall': {}, 'cramer': {}, 'biserial': {}, 'regr_avgx': {}, 'regr_avgy': {}, 'regr_count': {}, 'regr_intercept': {}, 'regr_r2': {}, 'regr_slope': {}, 'regr_sxx': {}, 'regr_sxy': {}, 'regr_syy': {}, 'approx_unique': 3})
# setattr(vdf_save, '"embarked"', save_vColumn)
# setattr(vdf_save, 'embarked', save_vColumn)
# save_vColumn = vColumn('"home.dest"', parent = vdf_save, transformations = [('"home.dest"', 'varchar(100)', 'text')], catalog = {'cov': {}, 'pearson': {}, 'spearman': {}, 'kendall': {}, 'cramer': {}, 'biserial': {}, 'regr_avgx': {}, 'regr_avgy': {}, 'regr_count': {}, 'regr_intercept': {}, 'regr_r2': {}, 'regr_slope': {}, 'regr_sxx': {}, 'regr_sxy': {}, 'regr_syy': {}, 'approx_unique': 355})
# setattr(vdf_save, '"home.dest"', save_vColumn)
# setattr(vdf_save, 'home.dest', save_vColumn)
# save_vColumn = vColumn('"sibsp"', parent = vdf_save, transformations = [('"sibsp"', 'int', 'int'), ('({} - 0.504051863857374) / (1.04111727241629)', 'float', 'float')], catalog = {'cov': {}, 'pearson': {}, 'spearman': {}, 'kendall': {}, 'cramer': {}, 'biserial': {}, 'regr_avgx': {}, 'regr_avgy': {}, 'regr_count': {}, 'regr_intercept': {}, 'regr_r2': {}, 'regr_slope': {}, 'regr_sxx': {}, 'regr_sxy': {}, 'regr_syy': {}, 'mean': 0, 'std': 1})
# setattr(vdf_save, '"sibsp"', save_vColumn)
# setattr(vdf_save, 'sibsp', save_vColumn)
# save_vColumn = vColumn('"fare"', parent = vdf_save, transformations = [('"fare"', 'numeric(10,5)', 'float'), ('({} - 33.9637936739659) / (52.6460729831293)', 'float', 'float')], catalog = {'cov': {}, 'pearson': {}, 'spearman': {}, 'kendall': {}, 'cramer': {}, 'biserial': {}, 'regr_avgx': {}, 'regr_avgy': {}, 'regr_count': {}, 'regr_intercept': {}, 'regr_r2': {}, 'regr_slope': {}, 'regr_sxx': {}, 'regr_sxy': {}, 'regr_syy': {}, 'mean': 0, 'std': 1})
# setattr(vdf_save, '"fare"', save_vColumn)
# setattr(vdf_save, 'fare', save_vColumn)
# save_vColumn = vColumn('"sex"', parent = vdf_save, transformations = [('"sex"', 'varchar(20)', 'text')], catalog = {'cov': {}, 'pearson': {}, 'spearman': {}, 'kendall': {}, 'cramer': {}, 'biserial': {}, 'regr_avgx': {}, 'regr_avgy': {}, 'regr_count': {}, 'regr_intercept': {}, 'regr_r2': {}, 'regr_slope': {}, 'regr_sxx': {}, 'regr_sxy': {}, 'regr_syy': {}, 'approx_unique': 2})
# setattr(vdf_save, '"sex"', save_vColumn)
# setattr(vdf_save, 'sex', save_vColumn)
# save_vColumn = vColumn('"body"', parent = vdf_save, transformations = [('"body"', 'int', 'int'), ('({} - 164.14406779661) / (96.5760207557808)', 'float', 'float')], catalog = {'cov': {}, 'pearson': {}, 'spearman': {}, 'kendall': {}, 'cramer': {}, 'biserial': {}, 'regr_avgx': {}, 'regr_avgy': {}, 'regr_count': {}, 'regr_intercept': {}, 'regr_r2': {}, 'regr_slope': {}, 'regr_sxx': {}, 'regr_sxy': {}, 'regr_syy': {}, 'mean': 0, 'std': 1})
# setattr(vdf_save, '"body"', save_vColumn)
# setattr(vdf_save, 'body', save_vColumn)
# save_vColumn = vColumn('"pclass"', parent = vdf_save, transformations = [('"pclass"', 'int', 'int'), ('({} - 2.28444084278768) / (0.842485636190292)', 'float', 'float')], catalog = {'cov': {}, 'pearson': {}, 'spearman': {}, 'kendall': {}, 'cramer': {}, 'biserial': {}, 'regr_avgx': {}, 'regr_avgy': {}, 'regr_count': {}, 'regr_intercept': {}, 'regr_r2': {}, 'regr_slope': {}, 'regr_sxx': {}, 'regr_sxy': {}, 'regr_syy': {}, 'mean': 0, 'std': 1})
# setattr(vdf_save, '"pclass"', save_vColumn)
# setattr(vdf_save, 'pclass', save_vColumn)
# save_vColumn = vColumn('"age"', parent = vdf_save, transformations = [('"age"', 'numeric(6,3)', 'float'), ('({} - 30.1524573721163) / (14.4353046299159)', 'float', 'float')], catalog = {'cov': {}, 'pearson': {}, 'spearman': {}, 'kendall': {}, 'cramer': {}, 'biserial': {}, 'regr_avgx': {}, 'regr_avgy': {}, 'regr_count': {}, 'regr_intercept': {}, 'regr_r2': {}, 'regr_slope': {}, 'regr_sxx': {}, 'regr_sxy': {}, 'regr_syy': {}, 'mean': 0, 'std': 1})
# setattr(vdf_save, '"age"', save_vColumn)
# setattr(vdf_save, 'age', save_vColumn)
# save_vColumn = vColumn('"name"', parent = vdf_save, transformations = [('"name"', 'varchar(164)', 'text')], catalog = {'cov': {}, 'pearson': {}, 'spearman': {}, 'kendall': {}, 'cramer': {}, 'biserial': {}, 'regr_avgx': {}, 'regr_avgy': {}, 'regr_count': {}, 'regr_intercept': {}, 'regr_r2': {}, 'regr_slope': {}, 'regr_sxx': {}, 'regr_sxy': {}, 'regr_syy': {}, 'approx_unique': 1233})
# setattr(vdf_save, '"name"', save_vColumn)
# setattr(vdf_save, 'name', save_vColumn)
# save_vColumn = vColumn('"cabin"', parent = vdf_save, transformations = [('"cabin"', 'varchar(30)', 'text')], catalog = {'cov': {}, 'pearson': {}, 'spearman': {}, 'kendall': {}, 'cramer': {}, 'biserial': {}, 'regr_avgx': {}, 'regr_avgy': {}, 'regr_count': {}, 'regr_intercept': {}, 'regr_r2': {}, 'regr_slope': {}, 'regr_sxx': {}, 'regr_sxy': {}, 'regr_syy': {}, 'approx_unique': 181})
# setattr(vdf_save, '"cabin"', save_vColumn)
# setattr(vdf_save, 'cabin', save_vColumn)
# save_vColumn = vColumn('"parch"', parent = vdf_save, transformations = [('"parch"', 'int', 'int'), ('({} - 0.378444084278768) / (0.868604707790392)', 'float', 'float')], catalog = {'cov': {}, 'pearson': {}, 'spearman': {}, 'kendall': {}, 'cramer': {}, 'biserial': {}, 'regr_avgx': {}, 'regr_avgy': {}, 'regr_count': {}, 'regr_intercept': {}, 'regr_r2': {}, 'regr_slope': {}, 'regr_sxx': {}, 'regr_sxy': {}, 'regr_syy': {}, 'mean': 0, 'std': 1})
# setattr(vdf_save, '"parch"', save_vColumn)
# setattr(vdf_save, 'parch', save_vColumn)
# save_vColumn = vColumn('"embarked_C"', parent = vdf_save, transformations = [('"embarked"', 'varchar(20)', 'text'), ("DECODE({}, 'C', 1, 0)", 'bool', 'int'), ('({} - 0.205024311183144) / (0.403883067551986)', 'float', 'float')], catalog = {'cov': {}, 'pearson': {}, 'spearman': {}, 'kendall': {}, 'cramer': {}, 'biserial': {}, 'regr_avgx': {}, 'regr_avgy': {}, 'regr_count': {}, 'regr_intercept': {}, 'regr_r2': {}, 'regr_slope': {}, 'regr_sxx': {}, 'regr_sxy': {}, 'regr_syy': {}, 'count': 1234, 'percent': 100.0, 'mean': 0, 'std': 1})
# setattr(vdf_save, '"embarked_C"', save_vColumn)
# setattr(vdf_save, 'embarked_C', save_vColumn)
# save_vColumn = vColumn('"embarked_Q"', parent = vdf_save, transformations = [('"embarked"', 'varchar(20)', 'text'), ("DECODE({}, 'Q', 1, 0)", 'bool', 'int'), ('({} - 0.0858995137763371) / (0.2803292172145)', 'float', 'float')], catalog = {'cov': {}, 'pearson': {}, 'spearman': {}, 'kendall': {}, 'cramer': {}, 'biserial': {}, 'regr_avgx': {}, 'regr_avgy': {}, 'regr_count': {}, 'regr_intercept': {}, 'regr_r2': {}, 'regr_slope': {}, 'regr_sxx': {}, 'regr_sxy': {}, 'regr_syy': {}, 'count': 1234, 'percent': 100.0, 'mean': 0, 'std': 1})
# setattr(vdf_save, '"embarked_Q"', save_vColumn)
# setattr(vdf_save, 'embarked_Q', save_vColumn)
# save_vColumn = vColumn('"sibsp_0"', parent = vdf_save, transformations = [('"sibsp"', 'int', 'int'), ("DECODE({}, '0', 1, 0)", 'bool', 'int'), ('({} - 0.677471636952998) / (0.467633436818381)', 'float', 'float')], catalog = {'cov': {}, 'pearson': {}, 'spearman': {}, 'kendall': {}, 'cramer': {}, 'biserial': {}, 'regr_avgx': {}, 'regr_avgy': {}, 'regr_count': {}, 'regr_intercept': {}, 'regr_r2': {}, 'regr_slope': {}, 'regr_sxx': {}, 'regr_sxy': {}, 'regr_syy': {}, 'count': 1234, 'percent': 100.0, 'mean': 0, 'std': 1})
# setattr(vdf_save, '"sibsp_0"', save_vColumn)
# setattr(vdf_save, 'sibsp_0', save_vColumn)
# save_vColumn = vColumn('"sibsp_1"', parent = vdf_save, transformations = [('"sibsp"', 'int', 'int'), ("DECODE({}, '1', 1, 0)", 'bool', 'int'), ('({} - 0.246353322528363) / (0.43106141275508)', 'float', 'float')], catalog = {'cov': {}, 'pearson': {}, 'spearman': {}, 'kendall': {}, 'cramer': {}, 'biserial': {}, 'regr_avgx': {}, 'regr_avgy': {}, 'regr_count': {}, 'regr_intercept': {}, 'regr_r2': {}, 'regr_slope': {}, 'regr_sxx': {}, 'regr_sxy': {}, 'regr_syy': {}, 'count': 1234, 'percent': 100.0, 'mean': 0, 'std': 1})
# setattr(vdf_save, '"sibsp_1"', save_vColumn)
# setattr(vdf_save, 'sibsp_1', save_vColumn)
# save_vColumn = vColumn('"sibsp_2"', parent = vdf_save, transformations = [('"sibsp"', 'int', 'int'), ("DECODE({}, '2', 1, 0)", 'bool', 'int'), ('({} - 0.0307941653160454) / (0.172829657775055)', 'float', 'float')], catalog = {'cov': {}, 'pearson': {}, 'spearman': {}, 'kendall': {}, 'cramer': {}, 'biserial': {}, 'regr_avgx': {}, 'regr_avgy': {}, 'regr_count': {}, 'regr_intercept': {}, 'regr_r2': {}, 'regr_slope': {}, 'regr_sxx': {}, 'regr_sxy': {}, 'regr_syy': {}, 'count': 1234, 'percent': 100.0, 'mean': 0, 'std': 1})
# setattr(vdf_save, '"sibsp_2"', save_vColumn)
# setattr(vdf_save, 'sibsp_2', save_vColumn)
# save_vColumn = vColumn('"sibsp_3"', parent = vdf_save, transformations = [('"sibsp"', 'int', 'int'), ("DECODE({}, '3', 1, 0)", 'bool', 'int'), ('({} - 0.0162074554294976) / (0.126323812118054)', 'float', 'float')], catalog = {'cov': {}, 'pearson': {}, 'spearman': {}, 'kendall': {}, 'cramer': {}, 'biserial': {}, 'regr_avgx': {}, 'regr_avgy': {}, 'regr_count': {}, 'regr_intercept': {}, 'regr_r2': {}, 'regr_slope': {}, 'regr_sxx': {}, 'regr_sxy': {}, 'regr_syy': {}, 'count': 1234, 'percent': 100.0, 'mean': 0, 'std': 1})
# setattr(vdf_save, '"sibsp_3"', save_vColumn)
# setattr(vdf_save, 'sibsp_3', save_vColumn)
# save_vColumn = vColumn('"sibsp_4"', parent = vdf_save, transformations = [('"sibsp"', 'int', 'int'), ("DECODE({}, '4', 1, 0)", 'bool', 'int'), ('({} - 0.0178282009724473) / (0.132380352193528)', 'float', 'float')], catalog = {'cov': {}, 'pearson': {}, 'spearman': {}, 'kendall': {}, 'cramer': {}, 'biserial': {}, 'regr_avgx': {}, 'regr_avgy': {}, 'regr_count': {}, 'regr_intercept': {}, 'regr_r2': {}, 'regr_slope': {}, 'regr_sxx': {}, 'regr_sxy': {}, 'regr_syy': {}, 'count': 1234, 'percent': 100.0, 'mean': 0, 'std': 1})
# setattr(vdf_save, '"sibsp_4"', save_vColumn)
# setattr(vdf_save, 'sibsp_4', save_vColumn)
# save_vColumn = vColumn('"sibsp_5"', parent = vdf_save, transformations = [('"sibsp"', 'int', 'int'), ("DECODE({}, '5', 1, 0)", 'bool', 'int'), ('({} - 0.00486223662884927) / (0.0695882140149223)', 'float', 'float')], catalog = {'cov': {}, 'pearson': {}, 'spearman': {}, 'kendall': {}, 'cramer': {}, 'biserial': {}, 'regr_avgx': {}, 'regr_avgy': {}, 'regr_count': {}, 'regr_intercept': {}, 'regr_r2': {}, 'regr_slope': {}, 'regr_sxx': {}, 'regr_sxy': {}, 'regr_syy': {}, 'count': 1234, 'percent': 100.0, 'mean': 0, 'std': 1})
# setattr(vdf_save, '"sibsp_5"', save_vColumn)
# setattr(vdf_save, 'sibsp_5', save_vColumn)
# save_vColumn = vColumn('"sex_female"', parent = vdf_save, transformations = [('"sex"', 'varchar(20)', 'text'), ("DECODE({}, 'female', 1, 0)", 'bool', 'int'), ('({} - 0.340356564019449) / (0.474021160833511)', 'float', 'float')], catalog = {'cov': {}, 'pearson': {}, 'spearman': {}, 'kendall': {}, 'cramer': {}, 'biserial': {}, 'regr_avgx': {}, 'regr_avgy': {}, 'regr_count': {}, 'regr_intercept': {}, 'regr_r2': {}, 'regr_slope': {}, 'regr_sxx': {}, 'regr_sxy': {}, 'regr_syy': {}, 'count': 1234, 'percent': 100.0, 'mean': 0, 'std': 1})
# setattr(vdf_save, '"sex_female"', save_vColumn)
# setattr(vdf_save, 'sex_female', save_vColumn)
# save_vColumn = vColumn('"pclass_1"', parent = vdf_save, transformations = [('"pclass"', 'int', 'int'), ("DECODE({}, '1', 1, 0)", 'bool', 'int'), ('({} - 0.252836304700162) / (0.434814120621594)', 'float', 'float')], catalog = {'cov': {}, 'pearson': {}, 'spearman': {}, 'kendall': {}, 'cramer': {}, 'biserial': {}, 'regr_avgx': {}, 'regr_avgy': {}, 'regr_count': {}, 'regr_intercept': {}, 'regr_r2': {}, 'regr_slope': {}, 'regr_sxx': {}, 'regr_sxy': {}, 'regr_syy': {}, 'count': 1234, 'percent': 100.0, 'mean': 0, 'std': 1})
# setattr(vdf_save, '"pclass_1"', save_vColumn)
# setattr(vdf_save, 'pclass_1', save_vColumn)
# save_vColumn = vColumn('"pclass_2"', parent = vdf_save, transformations = [('"pclass"', 'int', 'int'), ("DECODE({}, '2', 1, 0)", 'bool', 'int'), ('({} - 0.209886547811994) / (0.407392539646775)', 'float', 'float')], catalog = {'cov': {}, 'pearson': {}, 'spearman': {}, 'kendall': {}, 'cramer': {}, 'biserial': {}, 'regr_avgx': {}, 'regr_avgy': {}, 'regr_count': {}, 'regr_intercept': {}, 'regr_r2': {}, 'regr_slope': {}, 'regr_sxx': {}, 'regr_sxy': {}, 'regr_syy': {}, 'count': 1234, 'percent': 100.0, 'mean': 0, 'std': 1})
# setattr(vdf_save, '"pclass_2"', save_vColumn)
# setattr(vdf_save, 'pclass_2', save_vColumn)
# save_vColumn = vColumn('"parch_0"', parent = vdf_save, transformations = [('"parch"', 'int', 'int'), ("DECODE({}, '0', 1, 0)", 'bool', 'int'), ('({} - 0.76904376012966) / (0.421615353846742)', 'float', 'float')], catalog = {'cov': {}, 'pearson': {}, 'spearman': {}, 'kendall': {}, 'cramer': {}, 'biserial': {}, 'regr_avgx': {}, 'regr_avgy': {}, 'regr_count': {}, 'regr_intercept': {}, 'regr_r2': {}, 'regr_slope': {}, 'regr_sxx': {}, 'regr_sxy': {}, 'regr_syy': {}, 'count': 1234, 'percent': 100.0, 'mean': 0, 'std': 1})
# setattr(vdf_save, '"parch_0"', save_vColumn)
# setattr(vdf_save, 'parch_0', save_vColumn)
# save_vColumn = vColumn('"parch_1"', parent = vdf_save, transformations = [('"parch"', 'int', 'int'), ("DECODE({}, '1', 1, 0)", 'bool', 'int'), ('({} - 0.132090761750405) / (0.338726690940442)', 'float', 'float')], catalog = {'cov': {}, 'pearson': {}, 'spearman': {}, 'kendall': {}, 'cramer': {}, 'biserial': {}, 'regr_avgx': {}, 'regr_avgy': {}, 'regr_count': {}, 'regr_intercept': {}, 'regr_r2': {}, 'regr_slope': {}, 'regr_sxx': {}, 'regr_sxy': {}, 'regr_syy': {}, 'count': 1234, 'percent': 100.0, 'mean': 0, 'std': 1})
# setattr(vdf_save, '"parch_1"', save_vColumn)
# setattr(vdf_save, 'parch_1', save_vColumn)
# save_vColumn = vColumn('"parch_2"', parent = vdf_save, transformations = [('"parch"', 'int', 'int'), ("DECODE({}, '2', 1, 0)", 'bool', 'int'), ('({} - 0.0794165316045381) / (0.270497393976763)', 'float', 'float')], catalog = {'cov': {}, 'pearson': {}, 'spearman': {}, 'kendall': {}, 'cramer': {}, 'biserial': {}, 'regr_avgx': {}, 'regr_avgy': {}, 'regr_count': {}, 'regr_intercept': {}, 'regr_r2': {}, 'regr_slope': {}, 'regr_sxx': {}, 'regr_sxy': {}, 'regr_syy': {}, 'count': 1234, 'percent': 100.0, 'mean': 0, 'std': 1})
# setattr(vdf_save, '"parch_2"', save_vColumn)
# setattr(vdf_save, 'parch_2', save_vColumn)
# save_vColumn = vColumn('"parch_3"', parent = vdf_save, transformations = [('"parch"', 'int', 'int'), ("DECODE({}, '3', 1, 0)", 'bool', 'int'), ('({} - 0.00648298217179903) / (0.0802880870379623)', 'float', 'float')], catalog = {'cov': {}, 'pearson': {}, 'spearman': {}, 'kendall': {}, 'cramer': {}, 'biserial': {}, 'regr_avgx': {}, 'regr_avgy': {}, 'regr_count': {}, 'regr_intercept': {}, 'regr_r2': {}, 'regr_slope': {}, 'regr_sxx': {}, 'regr_sxy': {}, 'regr_syy': {}, 'count': 1234, 'percent': 100.0, 'mean': 0, 'std': 1})
# setattr(vdf_save, '"parch_3"', save_vColumn)
# setattr(vdf_save, 'parch_3', save_vColumn)
# save_vColumn = vColumn('"parch_4"', parent = vdf_save, transformations = [('"parch"', 'int', 'int'), ("DECODE({}, '4', 1, 0)", 'bool', 'int'), ('({} - 0.00486223662884927) / (0.0695882140149223)', 'float', 'float')], catalog = {'cov': {}, 'pearson': {}, 'spearman': {}, 'kendall': {}, 'cramer': {}, 'biserial': {}, 'regr_avgx': {}, 'regr_avgy': {}, 'regr_count': {}, 'regr_intercept': {}, 'regr_r2': {}, 'regr_slope': {}, 'regr_sxx': {}, 'regr_sxy': {}, 'regr_syy': {}, 'count': 1234, 'percent': 100.0, 'mean': 0, 'std': 1})
# setattr(vdf_save, '"parch_4"', save_vColumn)
# setattr(vdf_save, 'parch_4', save_vColumn)
# save_vColumn = vColumn('"parch_5"', parent = vdf_save, transformations = [('"parch"', 'int', 'int'), ("DECODE({}, '5', 1, 0)", 'bool', 'int'), ('({} - 0.00486223662884927) / (0.0695882140149223)', 'float', 'float')], catalog = {'cov': {}, 'pearson': {}, 'spearman': {}, 'kendall': {}, 'cramer': {}, 'biserial': {}, 'regr_avgx': {}, 'regr_avgy': {}, 'regr_count': {}, 'regr_intercept': {}, 'regr_r2': {}, 'regr_slope': {}, 'regr_sxx': {}, 'regr_sxy': {}, 'regr_syy': {}, 'count': 1234, 'percent': 100.0, 'mean': 0, 'std': 1})
# setattr(vdf_save, '"parch_5"', save_vColumn)
# setattr(vdf_save, 'parch_5', save_vColumn)
# save_vColumn = vColumn('"parch_6"', parent = vdf_save, transformations = [('"parch"', 'int', 'int'), ("DECODE({}, '6', 1, 0)", 'bool', 'int'), ('({} - 0.00162074554294976) / (0.0402421553806318)', 'float', 'float')], catalog = {'cov': {}, 'pearson': {}, 'spearman': {}, 'kendall': {}, 'cramer': {}, 'biserial': {}, 'regr_avgx': {}, 'regr_avgy': {}, 'regr_count': {}, 'regr_intercept': {}, 'regr_r2': {}, 'regr_slope': {}, 'regr_sxx': {}, 'regr_sxy': {}, 'regr_syy': {}, 'count': 1234, 'percent': 100.0, 'mean': 0, 'std': 1})
# setattr(vdf_save, '"parch_6"', save_vColumn)
# setattr(vdf_save, 'parch_6', save_vColumn)

# %% [markdown]
# ### See Also
#
# <table id="seealso">
#     <tr><td><a href="../../utilities/read_vdf">read_vdf</a></td> <td>Loads a .vdf text file and returns a vDataFrame.</td></tr>
# </table>
